# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyeo import classification as cls

from tpot import TPOTClassifier

from sklearn.svm import SVC

from sklearn.model_selection import train_test_split

# %%
band_labels = ["band_{}".format(number) for number in range(1,13)]

training_data = pd.read_csv("data/training_for_SVM_just_data.csv", names=
                           ["class"]+band_labels + ["segment_id"])

# %%
training_data
# Out:
#        class  band_1  band_2  band_3  band_4  band_5  band_6  band_7  band_8  \
# 0          1    7573   24811    47.0    6821     724    6674     382     522
# 1          1    7977   31234    48.0    7248     726    9051     374     516
# 2          1    7172   22947   145.0    6467     723    5725     401     553
# 3          1    7807   26235   107.0    6919     724    9087     428     627
# 4          1    7722   26577    48.0    6921     724    8942     444     627
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 14282      3    7301   25182    61.0    6574     723    5050     337     445
# 14283      3    7301   25182    61.0    6574     723    5050     337     445
# 14284      3    7330   23172   101.0    6497     724    5368     370     509
# 14285      3    6551   16785   302.0    6059     723    3944     420     560
# 14286      3    7187   24145    73.0    6446     724    4501     350     444
#
# ...

# %%
# %matplotlib inline
training_data.groupby(by="class").mean().drop(['segment_id'], axis=1).transpose().plot()

# %%
def normalise(data):
    return ((data-data.min())/(data.max()-data.min())*np.iinfo(np.uint32).max).fillna(0).astype('uint32')

normalised_bands = training_data.drop(['class', 'segment_id'], axis=1).apply(normalise, axis=0)
normalised_bands.describe()
normalised_bands.dtypes
# Out:
# band_1     uint32
# band_2     uint32
# band_3     uint32
# band_4     uint32
# band_5     uint32
# band_6     uint32
# band_7     uint32
# band_8     uint32
# band_9     uint32
# band_10    uint32
# band_11    uint32
# band_12    uint32
# dtype: object

# %%
preproc_training = pd.concat([training_data[["class", "segment_id"]], normalised_bands], axis = 1)
label_order = ["class"] + band_labels + ["segment_id"]
preproc_training = preproc_training[label_order]
preproc_training
# Out:
#        class      band_1      band_2     band_3      band_4      band_5  \
# 0          1  3924227245  3247427472   21831416  3936234328  4079238344
# 1          1  4151165094  4114929829   22559130  4285958019  4118461789
# 2          1  3698974579  2995672157   93147376  3646299465  4059626621
# 3          1  4055671445  3439755568   65494248  4016498782  4079238344
# 4          1  4007924620  3485946725   22559130  4018136832  4079238344
# ...      ...         ...         ...        ...         ...         ...
# 14282      3  3771437407  3297535424   32019410  3733935144  4059626621
# 14283      3  3771437407  3297535424   32019410  3733935144  4059626621
# 14284      3  3787727500  3026061076   61127965  3670870216  4079238344
# 14285      3  3350141897  2163420947  207398454  3312137250  4059626621
# 14286      3  3707400490  3157476271   40751977  3629099939  4079238344
#
#            band_6     band_7     band_8     band_9     band_10     band_11  \
# ...

# %%
for i in range(1,13):
    preproc_training.plot.scatter(x='class', y='band_{}'.format(i))

# %%
preproc_training.groupby(by="class").mean().drop(['segment_id'], axis=1).transpose().plot.scatter(x='class', y='band_5')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/eoenv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'class'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-61151a932433> in <module>
# ----> 1 preproc_training.groupby(by="class").mean().drop(['segment_id'], axis=1).transpose().plot.scatter(x='class', y='band_5')
#
# ...

# %%
labels = preproc_training['class']
features = preproc_training.loc[:,'band_1':].drop(["segment_id"], axis = 1)
labels
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14282    3
# 14283    3
# 14284    3
# 14285    3
# 14286    3
# Name: class, Length: 14287, dtype: int64

# %%
f_train, f_test, l_train, l_test = train_test_split(features, labels)
model = SVC(kernel='rbf')
#model.fit(f_train, l_train)
#print(model.score(f_test, l_test))

# %%
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
C_range = np.logspace(0, 1, 2, base=10)  # base = 2 for a fine tuning
gamma_range = np.logspace(0, 128, 2, base=10)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
grid = GridSearchCV(SVC(class_weight='balanced'), param_grid=param_grid, cv=cv, n_jobs=6)
#grid.fit(f_train, l_train)

# %%
#grid.score(f_test, l_test)

# %%
searcher = TPOTClassifier(generations=5, population_size=20, cv=5,n_jobs = -1, verbosity=2)
searcher.fit(f_train, l_train)
searcher.score(f_test, l_test)

# %%
from sklearn.ensemble import ExtraTreesClassifier
searcher.export('tpot_v2_nomalised.pkl')
model = ExtraTreesClassifier(CombineDFs(GaussianNB(input_matrix), input_matrix), bootstrap=False, criterion=gini, max_features=0.4, min_samples_leaf=3, min_samples_split=2, n_estimators=100)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import make_pipeline, make_union
from tpot.builtins import StackingEstimator
from sklearn.preprocessing import FunctionTransformer
from copy import copy
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier

# Average CV score on the training set was:0.8129780700079303
exported_pipeline = make_pipeline(
    make_union(
        StackingEstimator(estimator=GaussianNB()),
        FunctionTransformer(copy)
    ),
    ExtraTreesClassifier(bootstrap=False, criterion="gini", max_features=0.4, min_samples_leaf=3, min_samples_split=2, n_estimators=100)
)

training_data = training_data[training_data['class'] != 5]
labels = training_data['class']
features = training_data.loc[:,'band_1':].drop(["segment_id"], axis = 1)

features

#model = exported_pipeline.fit(features, labels)
#joblib.dump(model, "extra_trees_no_builtup.pkl")
# Out:
#        band_1  band_2  band_3  band_4  band_5  band_6  band_7  band_8  band_9  \
# 0        7573   24811    47.0    6821     724    6674     382     522     381
# 1        7977   31234    48.0    7248     726    9051     374     516     363
# 2        7172   22947   145.0    6467     723    5725     401     553     425
# 3        7807   26235   107.0    6919     724    9087     428     627     423
# 4        7722   26577    48.0    6921     724    8942     444     627     442
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 14282    7301   25182    61.0    6574     723    5050     337     445     336
# 14283    7301   25182    61.0    6574     723    5050     337     445     336
# 14284    7330   23172   101.0    6497     724    5368     370     509     369
# 14285    6551   16785   302.0    6059     723    3944     420     560     476
# 14286    7187   24145    73.0    6446     724    4501     350     444     335
#
#        band_10  band_11  band_12
# ...

# %%
import joblib
from pyeo.classification import classify_image
from pyeo.filesystem_utilities import init_log
init_log("ExtraTrees.log")
image_path = "data/s2_20180219_testsite_vegIndex_s1.tif"
output_path = "outputs/extra_trees_test.tif"
model_path = "tpot_no_preproc.pkl"
classify_image(image_path, model_path, output_path, apply_mask=False)
# Out:
# 2019-10-01 14:52:35,375: INFO: ****PROCESSING START****
# 2019-10-01 14:52:35,380: INFO: Classifying file: data/s2_20180219_testsite_vegIndex_s1.tif
# 2019-10-01 14:52:35,384: INFO: Saved model     : tpot_no_preproc.pkl
# 2019-10-01 14:52:35,512: WARNING: Sklearn joblib import failed,trying generic joblib
# 2019-10-01 14:52:36,241: INFO: Created classification image file: outputs/extra_trees_test.tif
# 2019-10-01 14:52:36,251: INFO: Reshaping image from GDAL to Scikit-Learn dimensions
# 2019-10-01 14:52:36,252: INFO: Finding good pixels without missing values
# 2019-10-01 14:52:36,253: INFO: image_array.shape = (78332736, 12)
# 2019-10-01 14:52:58,650: INFO: No. good values: 8262302
# 2019-10-01 14:52:58,651: INFO: Filtering nodata values
# 2019-10-01 14:53:13,338: INFO:    All  samples: 78332736
# 2019-10-01 14:53:13,360: INFO:    Good samples: 8262302
# 2019-10-01 14:53:13,362: INFO:    Number of chunks 10 Chunk size 826230 Chunk residual 2
# ...
